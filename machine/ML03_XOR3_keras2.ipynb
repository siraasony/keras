# %%
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

from keras.layers import Dense
from keras.models import Sequential
import numpy as np

from keras.utils import to_categorical

#1. 데이터
x_train = [ [0,0], [1,0], [0,1], [1,1] ]
y_train = [ 0, 1, 1, 0]

x_train = np.array(x_train)
y_train = np.array(y_train)

# #2. 모델

model=Sequential()

model.add(Dense(8, activation='relu',input_shape=(2,)))
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1,activation='sigmoid'))


# #3. 훈련
model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
model.fit(x_train,y_train,batch_size=2,epochs=20,verbose=2)

# #4. 평가

x_test =np.array( [ [0,0], [1,0], [0,1], [1,1] ] )
y_predict = model.predict(x_test)

print(y_predict)
#y_predict

y_predict[y_predict>0.5]=1
y_predict[y_predict<0.5]=0

print(x_test,"의 예측 결과:",y_predict.astype(int))
# Out:
# Epoch 1/20
#  - 0s - loss: 0.6980 - accuracy: 0.5000
# Epoch 2/20
#  - 0s - loss: 0.6978 - accuracy: 0.2500
# Epoch 3/20
#  - 0s - loss: 0.6861 - accuracy: 0.2500
# Epoch 4/20
#  - 0s - loss: 0.6892 - accuracy: 0.2500
# Epoch 5/20
#  - 0s - loss: 0.6812 - accuracy: 0.5000
# Epoch 6/20
#  - 0s - loss: 0.6798 - accuracy: 0.2500
# Epoch 7/20
#  - 0s - loss: 0.6787 - accuracy: 0.2500
# Epoch 8/20
#  - 0s - loss: 0.6792 - accuracy: 0.7500
# Epoch 9/20
#  - 0s - loss: 0.6746 - accuracy: 0.7500
# Epoch 10/20
#  - 0s - loss: 0.6727 - accuracy: 0.7500
# Epoch 11/20
#  - 0s - loss: 0.6718 - accuracy: 0.7500
# Epoch 12/20
#  - 0s - loss: 0.6697 - accuracy: 0.7500
# Epoch 13/20
#  - 0s - loss: 0.6703 - accuracy: 0.5000
# Epoch 14/20
#  - 0s - loss: 0.6703 - accuracy: 0.7500
# Epoch 15/20
#  - 0s - loss: 0.6657 - accuracy: 0.7500
# Epoch 16/20
#  - 0s - loss: 0.6633 - accuracy: 0.7500
# Epoch 17/20
#  - 0s - loss: 0.6655 - accuracy: 0.7500
# Epoch 18/20
#  - 0s - loss: 0.6628 - accuracy: 0.7500
# Epoch 19/20
#  - 0s - loss: 0.6612 - accuracy: 0.7500
# Epoch 20/20
#  - 0s - loss: 0.6584 - accuracy: 0.5000
# [[0.50283885]
#  [0.50489867]
#  [0.5063612 ]
#  [0.4271146 ]]
# [[0 0]
#  [1 0]
#  [0 1]
#  [1 1]] 의 예측 결과: [[1]
#  [1]
#  [1]
#  [0]]
