# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, KFold
from sklearn.model_selection import cross_val_score

from sklearn.metrics import accuracy_score
from sklearn.utils.testing import all_estimators

import warnings
warnings.filterwarnings(action='ignore')

iris_data =pd.read_csv("./data/iris2.csv",encoding='utf-8')

y=iris_data.loc[:,'Name']
x=iris_data.iloc[:,:-1]

warnings.filterwarnings(action='ignore')
allAlgorithms= all_estimators(type_filter='classifier')

#kfold_cv = KFold(n_splits=10, shuffle=True)

#print(allAlgorithms)
#print(len(allAlgorithms))
#print(type(allAlgorithms))

print("start")
for i in range(4,12,2):

    print(i," \n")
    kfold_cv = KFold(n_splits=i, shuffle=True)

    li=[]
    na=[]
    for (name, algorithm) in allAlgorithms:
    
        try:
            clf=algorithm()
        
            if hasattr(clf,"score"):
                scores=cross_val_score(clf,x,y, cv=kfold_cv)
                print(name,"의 정답률:", scores.mean())
 
               
            
            
        except:
            print("\n오류:",name,"\n")
# Out:
# start
# 4
#
# AdaBoostClassifier 의 정답률: 0.9466571834992887
# BaggingClassifier 의 정답률: 0.9399004267425319
# BernoulliNB 의 정답률: 0.2736486486486487
# CalibratedClassifierCV 의 정답률: 0.9329658605974395
# ComplementNB 의 정답률: 0.6667852062588905
# DecisionTreeClassifier 의 정답률: 0.9535917496443812
# ExtraTreeClassifier 의 정답률: 0.9532361308677098
# ExtraTreesClassifier 의 정답률: 0.9532361308677098
# GaussianNB 의 정답률: 0.9532361308677099
# GaussianProcessClassifier 의 정답률: 0.9603485064011379
# GradientBoostingClassifier 의 정답률: 0.9466571834992888
# KNeighborsClassifier 의 정답률: 0.9599928876244666
# LabelPropagation 의 정답률: 0.9598150782361309
# LabelSpreading 의 정답률: 0.9601706970128022
# LinearDiscriminantAnalysis 의 정답률: 0.9799075391180654
# LinearSVC 의 정답률: 0.9464793741109531
# LogisticRegression 의 정답률: 0.9135846372688479
# LogisticRegressionCV 의 정답률: 0.9397226173541964
# MLPClassifier 의 정답률: 0.9669274537695591
# MultinomialNB 의 정답률: 0.6210881934566146
# NearestCentroid 의 정답률: 0.9201635846372689
# NuSVC 의 정답률: 0.9599928876244666
# PassiveAggressiveClassifier 의 정답률: 0.6996799431009957
# Perceptron 의 정답률: 0.7268847795163584
# QuadraticDiscriminantAnalysis 의 정답률: 0.9733285917496444
#
# 오류: RadiusNeighborsClassifier
#
# RandomForestClassifier 의 정답률: 0.9601706970128022
# RidgeClassifier 의 정답률: 0.8333926031294453
# RidgeClassifierCV 의 정답률: 0.8333926031294453
# SGDClassifier 의 정답률: 0.7279516358463727
# SVC 의 정답률: 0.9799075391180655
# 6
#
# AdaBoostClassifier 의 정답률: 0.9533333333333333
# BaggingClassifier 의 정답률: 0.9199999999999999
# BernoulliNB 의 정답률: 0.20000000000000004
# CalibratedClassifierCV 의 정답률: 0.9333333333333332
# ComplementNB 의 정답률: 0.6666666666666666
# DecisionTreeClassifier 의 정답률: 0.9466666666666667
# ExtraTreeClassifier 의 정답률: 0.9266666666666666
# ExtraTreesClassifier 의 정답률: 0.9533333333333333
# GaussianNB 의 정답률: 0.96
# GaussianProcessClassifier 의 정답률: 0.9533333333333333
# GradientBoostingClassifier 의 정답률: 0.94
# KNeighborsClassifier 의 정답률: 0.96
# LabelPropagation 의 정답률: 0.96
# LabelSpreading 의 정답률: 0.96
# LinearDiscriminantAnalysis 의 정답률: 0.98
# LinearSVC 의 정답률: 0.9466666666666667
# LogisticRegression 의 정답률: 0.96
# LogisticRegressionCV 의 정답률: 0.94
# MLPClassifier 의 정답률: 0.9666666666666667
# MultinomialNB 의 정답률: 0.8933333333333334
# NearestCentroid 의 정답률: 0.9333333333333332
# NuSVC 의 정답률: 0.96
# PassiveAggressiveClassifier 의 정답률: 0.7333333333333333
# Perceptron 의 정답률: 0.68
# QuadraticDiscriminantAnalysis 의 정답률: 0.9733333333333333
# RadiusNeighborsClassifier 의 정답률: 0.96
# RandomForestClassifier 의 정답률: 0.9533333333333333
# RidgeClassifier 의 정답률: 0.8066666666666668
# RidgeClassifierCV 의 정답률: 0.8133333333333334
# SGDClassifier 의 정답률: 0.7400000000000001
# SVC 의 정답률: 0.98
# 8
#
# AdaBoostClassifier 의 정답률: 0.9269005847953217
# BaggingClassifier 의 정답률: 0.9532163742690059
# BernoulliNB 의 정답률: 0.21966374269005848
# CalibratedClassifierCV 의 정답률: 0.9261695906432749
# ComplementNB 의 정답률: 0.6677631578947368
# DecisionTreeClassifier 의 정답률: 0.9470029239766081
# ExtraTreeClassifier 의 정답률: 0.9199561403508771
# ExtraTreesClassifier 의 정답률: 0.9470029239766081
# GaussianNB 의 정답률: 0.9539473684210527
# GaussianProcessClassifier 의 정답률: 0.9601608187134503
# GradientBoostingClassifier 의 정답률: 0.945906432748538
# KNeighborsClassifier 의 정답률: 0.9671052631578947
# LabelPropagation 의 정답률: 0.9597953216374269
# LabelSpreading 의 정답률: 0.9597953216374269
# LinearDiscriminantAnalysis 의 정답률: 0.9798976608187133
# LinearSVC 의 정답률: 0.9455409356725146
# LogisticRegression 의 정답률: 0.9473684210526315
# LogisticRegressionCV 의 정답률: 0.9265350877192982
# MLPClassifier 의 정답률: 0.9725877192982456
# MultinomialNB 의 정답률: 0.8249269005847952
# NearestCentroid 의 정답률: 0.9269005847953217
# NuSVC 의 정답률: 0.9535818713450293
# PassiveAggressiveClassifier 의 정답률: 0.7068713450292398
# Perceptron 의 정답률: 0.7653508771929824
# QuadraticDiscriminantAnalysis 의 정답률: 0.9729532163742689
# RadiusNeighborsClassifier 의 정답률: 0.9594298245614035
# RandomForestClassifier 의 정답률: 0.945906432748538
# RidgeClassifier 의 정답률: 0.7989766081871345
# RidgeClassifierCV 의 정답률: 0.8333333333333333
# SGDClassifier 의 정답률: 0.810672514619883
# SVC 의 정답률: 0.9798976608187133
# 10
#
# AdaBoostClassifier 의 정답률: 0.9400000000000001
# BaggingClassifier 의 정답률: 0.9400000000000001
# BernoulliNB 의 정답률: 0.22000000000000003
# CalibratedClassifierCV 의 정답률: 0.9333333333333333
# ComplementNB 의 정답률: 0.6666666666666667
# DecisionTreeClassifier 의 정답률: 0.9466666666666667
# ExtraTreeClassifier 의 정답률: 0.9466666666666667
# ExtraTreesClassifier 의 정답률: 0.9466666666666667
# GaussianNB 의 정답률: 0.9533333333333334
# GaussianProcessClassifier 의 정답률: 0.9533333333333335
# GradientBoostingClassifier 의 정답률: 0.9466666666666667
# KNeighborsClassifier 의 정답률: 0.96
# LabelPropagation 의 정답률: 0.96
# LabelSpreading 의 정답률: 0.9600000000000002
# LinearDiscriminantAnalysis 의 정답률: 0.9800000000000001
# LinearSVC 의 정답률: 0.96
# LogisticRegression 의 정답률: 0.9666666666666666
# LogisticRegressionCV 의 정답률: 0.9333333333333333
# MLPClassifier 의 정답률: 0.9733333333333334
# MultinomialNB 의 정답률: 0.8733333333333334
# NearestCentroid 의 정답률: 0.9333333333333332
# NuSVC 의 정답률: 0.9533333333333334
# PassiveAggressiveClassifier 의 정답률: 0.7533333333333332
# Perceptron 의 정답률: 0.54
# QuadraticDiscriminantAnalysis 의 정답률: 0.9733333333333334
# RadiusNeighborsClassifier 의 정답률: 0.9466666666666667
# RandomForestClassifier 의 정답률: 0.9466666666666667
# RidgeClassifier 의 정답률: 0.8266666666666668
# RidgeClassifierCV 의 정답률: 0.8266666666666665
# SGDClassifier 의 정답률: 0.6199999999999999
# SVC 의 정답률: 0.9866666666666667
